# %%
import requests
import json
import pprint

with open('city.list_JP.json', mode='r', encoding='utf-8') as f:
    city_list = json.loads(f.read())

city_list

# %%
# config.jsonによけたAPI_keyの取得
with open('config.json', mode='r', encoding='utf-8') as f:
    jsonfile = json.loads(f.read())
API_key = jsonfile['API_key']

# %%
# 明日からの作業：
# https://openweathermap.org/forecast5#name5
# ここを参考にして各地の天気データを取得する
city_name = 'Tokyo'
flg = False
for list in city_list:
    if city_name == list['name']:
        print("ありました")
        flg = True
if flg == False:
    print("ありませんでした")
# Out:
# ありました

# %%
# 特定の市町村の緯度経度を入手したい
city_name = 'Nagoya'
flg = False
for city in city_list:
    if city_name == city['name']:
        pprint.pprint(city)
        lat  = city['coord']['lat']
        lon  = city['coord']['lon']
        flg = True
if flg == False:
    print("ありませんでした")

# せっかくだからfoliumでも遊ぶ
# とりあえず地図の中央を可児市にしておく
import folium

m = folium.Map(location=(lat, lon),  zoom_start=5) #lat, lonの順番
# Out:
# {'coord': {'lat': 35.181469, 'lon': 136.906403},
#  'country': 'JP',
#  'id': 1856057,
#  'name': 'Nagoya',
#  'state': ''}

# %%
# 複数都市を指定するには配列入りオブジェクトとかにして、そこに都市名・coordを取得。
# そのデータをfolium.Markerに渡していけばよさそう。

folium.Marker(
    location=[35.689499, 139.691711],
    tooltip="Click me!",
    popup="Tokyo",
    icon=folium.Icon(color="red"),
).add_to(m)

folium.Marker(
    location=[35.950001, 137.266663],
    tooltip="Click me!",
    popup="Osaka",
    icon=folium.Icon(color="green"),
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_482f8953e8e0027d96972dd0d75b2ac9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_482f8953e8e0027d96972dd0d75b2ac9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_482f8953e8e0027d96972dd0d75b2ac9 = L.map(
#                 &quot;map_482f8953e8e0027d96972dd0d75b2ac9&quot;,
#                 {
#                     center: [35.181469, 136.906403],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7474c326bfcaef7c5a93cd474c56b14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7474c326bfcaef7c5a93cd474c56b14.addTo(map_482f8953e8e0027d96972dd0d75b2ac9);
#
#
#             var marker_eeec74d1dbecb544a2e95676848cb79d = L.marker(
#                 [35.689499, 139.691711],
#                 {
# }
#             ).addTo(map_482f8953e8e0027d96972dd0d75b2ac9);
#
#
#             var icon_c452281eb778403ae5209b968fed5be4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_15785d1688e8d5d7ff0fff531758b41e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41a14cac140bfcc85638477b5a32f579 = $(`&lt;div id=&quot;html_41a14cac140bfcc85638477b5a32f579&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tokyo&lt;/div&gt;`)[0];
#                 popup_15785d1688e8d5d7ff0fff531758b41e.setContent(html_41a14cac140bfcc85638477b5a32f579);
#
#
#
#         marker_eeec74d1dbecb544a2e95676848cb79d.bindPopup(popup_15785d1688e8d5d7ff0fff531758b41e)
#         ;
#
#
#
#
#             marker_eeec74d1dbecb544a2e95676848cb79d.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_eeec74d1dbecb544a2e95676848cb79d.setIcon(icon_c452281eb778403ae5209b968fed5be4);
#
#
#             var marker_3048502ca53baa96a32bf846436898c4 = L.marker(
#                 [35.950001, 137.266663],
#                 {
# }
#             ).addTo(map_482f8953e8e0027d96972dd0d75b2ac9);
#
#
#             var icon_1a27fb0111f3ae2e1d47489c0c9493c9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b1c09a231f1584ff3febfdf15e57a279 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ece6792de23f7c17914767d13638e7a = $(`&lt;div id=&quot;html_9ece6792de23f7c17914767d13638e7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Osaka&lt;/div&gt;`)[0];
#                 popup_b1c09a231f1584ff3febfdf15e57a279.setContent(html_9ece6792de23f7c17914767d13638e7a);
#
#
#
#         marker_3048502ca53baa96a32bf846436898c4.bindPopup(popup_b1c09a231f1584ff3febfdf15e57a279)
#         ;
#
#
#
#
#             marker_3048502ca53baa96a32bf846436898c4.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_3048502ca53baa96a32bf846436898c4.setIcon(icon_1a27fb0111f3ae2e1d47489c0c9493c9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
city_name = 'Wakkanai'
url = f'http://api.openweathermap.org/geo/1.0/direct?q={city_name}&limit=5&appid={API_key}'
jsondata = requests.get(url).json()
pprint.pprint(jsondata)
# Out:
# [{'country': 'JP',
#   'lat': 45.4158108,
#   'local_names': {'ar': 'واكاناي، هوكايدو',
#                   'ascii': 'Wakkanai',
#                   'de': 'Wakkanai',
#                   'en': 'Wakkanai',
#                   'es': 'Wakkanai',
#                   'feature_name': 'Wakkanai',
#                   'fr': 'Wakkanai',
#                   'hu': 'Vakkanai',
#                   'ja': '稚内市',
#                   'ko': '왓카나이시',
#                   'pl': 'Wakkanai',
#                   'ru': 'Вакканай-си',
#                   'uk': 'Вакканай',
#                   'zh': '稚內市'},
#   'lon': 141.6730309,
#   'name': 'Wakkanai'}]

# %%
jsondata[0]['local_names']['ja']
# Out:
# '稚内市'

# %%
# ...なんでBetter Commentsは一行目は色変えられないんですかね…
#* 取得したい都市名：稚内、札幌、仙台、新潟、東京、金沢、長野、大阪、福山、高知、福岡、鹿児島、那覇
#! 大阪市はid:1853909。1853908の方は岐阜県下呂市にある「小坂」という場所の模様
selected_cities_name = ['Wakkanai', 'Sapporo', 'Sendai', 'Niigata', 'Tokyo', 'Kanazawa', 'Nagano', 'Osaka', 'Fukuyama', 'Kochi', 'Fukuoka', 'Kagoshima', 'Naha', 'Nagoya', 'Aomori', 'Matsue']
# city_listより都市名だけを取得したリストを作成…city_namesに重複がないかの確認を軽量化するため
city_list_nameonly = []
for city in city_list:
    city_list_nameonly.append(city['name'])
city_list_nameonly
# Out:
# ['Shingū',
#  'Atsugi',
#  'Akashi',
#  'Zushi',
#  'Awazuchō',
#  'Zaōmachi',
#  'Zamami',
#  'Zama',
#  'Yuzawa',
#  'Yuza',
#  'Yusuhara',
#  'Yūrakuchō',
#  'Yura',
#  'Yukuhashi',
#  'Yūki',
#  'Yugawara',
#  'Yugawa',
#  'Yuasa',
#  'Yoshino-chō',
#  'Yoshikawa',
#  'Yoshii',
#  'Yoshii',
#  'Yoshie',
#  'Yoshida-kasugachō',
#  'Yoshida',
#  'Miimachi-yoromi',
#  'Yorii',
#  'Yono',
#  'Yonakuni',
#  'Yonago',
#  'Yonabaru',
#  'Yokota',
#  'Yokosuka',
#  'Yokohama',
#  'Yokodaidō',
#  'Yokkaichi',
#  'Youkaichi',
#  'Yobimatsu',
#  'Yawata',
#  'Yatsuzawa',
#  'Honmachi',
#  'Yatsuomachi-higashikumisaka',
#  'Yasugichō',
#  'Yasu-shi',
#  'Yashiro',
#  'Yashio',
#  'Yaotsu',
#  'Yao',
#  'Yanohama',
#  'Yanai',
#  'Yanagawa',
#  'Yanadachō',
#  'Yamato-Takada',
#  'Yamatominami',
#  'Yamata',
#  'Yamazakichō-nakabirose',
#  'Yamanashi',
#  'Yamakita',
#  'Yamaguchi',
#  'Yamaguchi',
#  'Yamaga',
#  'Yamae',
#  'Yakuin-Horibata',
#  'Yakage',
#  'Yaizu',
#  'Yaita',
#  'Yabutani',
#  'Yabuhana',
#  'Yabu',
#  'Warabo',
#  'Warabi',
#  'Wano',
#  'Wakinohamachō',
#  'Wakimachi',
#  'Wake',
#  'Wakayama',
#  'Wakasa',
#  'Wajima',
#  'Wadomari',
#  'Wadayama',
#  'Utsunomiya',
#  'Uto',
#  'Utazu',
#  'Usuki',
#  'Ushibukamachi',
#  'Usa',
#  'Ureshinomachi-shimojuku',
#  'Urayasu',
#  'Uozu',
#  'Uno',
#  'Umi',
#  'Uki',
#  'Uken',
#  'Ujiie',
#  'Uji',
#  'Uenohara',
#  'Ueno',
#  'Ueno-ebisumachi',
#  'Ueki',
#  'Uekimachi-mōno',
#  'Ueda',
#  'Ube',
#  'Tsuyama',
#  'Tsushima',
#  'Tsurusaki',
#  'Tsuruoka',
#  'Tsurugi-asahimachi',
#  'Tsurugasaki',
#  'Tsuruga',
#  'Tsunō',
#  'Tsunagi',
#  'Tsuma',
#  'Tsukumiura',
#  'Tsukawaki',
#  'Tsukasamachi',
#  'Tsukaguchichō',
#  'Tsuiki',
#  'Tsubota',
#  'Tsubata',
#  'Tsubame',
#  'Tsu',
#  'Tozawa',
#  'Toyota-shi',
#  'Toyota',
#  'Toyoshina',
#  'Toyooka',
#  'Toyonaka',
#  'Toyokawa',
#  'Toyohashi',
#  'Toyohama',
#  'Toyama-ken',
#  'Toyama',
#  'Tottori',
#  'Tottori',
#  'Totsuka chō',
#  'Tosu',
#  'Toriimatsu',
#  'Tonoshō',
#  'Tondabayashichō',
#  'Tonami',
#  'Tomioka',
#  'Tomigusuku',
#  'Tokyo Prefecture',
#  'Tokyo',
#  'Tokuyama',
#  'Tokushima-ken',
#  'Tokushima',
#  'Tokuda',
#  'Tokorozawa',
#  'Tokoname',
#  'Toki',
#  'Tokashiki',
#  'Tōkamachi',
#  'Tōkaichi',
#  'Tōji',
#  'Togitsu',
#  'Todaka',
#  'Tochio-honchō',
#  'Tochigi',
#  'Tochigi',
#  'Tōbō',
#  'Toba',
#  'Tenri',
#  'Tennō',
#  'Tenjin',
#  'Tenjimmae',
#  'Tawaramoto',
#  'Tatsuno',
#  'Tatsunochō-tominaga',
#  'Tateyama',
#  'Tatebayashi',
#  'Tarumizu',
#  'Tarui',
#  'Taragi',
#  'Tanushimarumachi-toyoki',
#  'Tanuma',
#  'Nishi-Tokyo-shi',
#  'Tanashichō',
#  'Tanabe',
#  'Tanabe',
#  'Tamba',
#  'Tamarai',
#  'Tamano',
#  'Tamana',
#  'Tamamura',
#  'Tamagawa',
#  'Taketoyo',
#  'Taketomi',
#  'Takeochō-takeo',
#  'Takenouchi',
#  'Takehara',
#  'Takefu',
#  'Takedamachi',
#  'Takayama',
#  'Takatsuki',
#  'Takatsu',
#  'Takatorichō',
#  'Takatachō',
#  'Takata',
#  'Takasaki',
#  'Takasagochō-takasemachi',
#  'Takarazuka',
#  'Takaoka',
#  'Takanabe',
#  'Takamori',
#  'Takamatsu',
#  'Takamatsu',
#  'Takajōmachi',
#  'Takaishi',
#  'Takahashi',
#  'Takaharu',
#  'Takahama',
#  'Bungo-Takada-shi',
#  'Tajimi',
#  'Tahara',
#  'Tagawa',
#  'Taga',
#  'Tadotsu',
#  'Tadami',
#  'Tachikawa',
#  'Tachiarai',
#  'Tabuse',
#  'Suzuka',
#  'Suzaka',
#  'Suwa',
#  'Susami',
#  'Susaki',
#  'Sumoto',
#  'Sukumo',
#  'Suita',
#  'Suibara',
#  'Suguri',
#  'Sugito',
#  'Sueyoshichō-ninokata',
#  'Shimosomeda',
#  'Sōka',
#  'Sōja',
#  'Soeda',
#  'Sobue',
#  'Shuzenji',
#  'Shōbu',
#  'Shōbara',
#  'Shizuoka',
#  'Shizuoka',
#  'Shitara',
#  'Shirone',
#  'Shirayamamachi',
#  'Shiraoka',
#  'Shirako',
#  'Shirahamachō-usazakiminami',
#  'Shirahama',
#  'Shiozawa',
#  'Shiozawa',
#  'Shiomidai',
#  'Shiojiri',
#  'Shiobaru',
#  'Shintō',
#  'Shinshiro',
#  'Shinjichō-shinji',
#  'Shin’ichi',
#  'Shingū',
#  'Shinagawa-ku',
#  'Shimoshirouzu',
#  'Shimo-satsume',
#  'Shimonoseki',
#  'Shimonita',
#  'Shimoku',
#  'Shimokodanaka',
#  'Shimodate',
#  'Shimoda',
#  'Minato',
#  'Nishishinminato',
#  'Shinbashichō',
#  'Shimane-ken',
#  'Shimada',
#  'Shimabara',
#  'Shiki',
#  'Shijōdōri',
#  'Shiida',
#  'Shiga',
#  'Shido',
#  'Nanabari',
#  'Shibushi',
#  'Shibukawa',
#  'Shibata',
#  'Seto',
#  'Setakamachi-takayanagi',
#  'Umegaoka',
#  'Seta',
#  'Kiire-sesekushichō',
#  'Senzaki',
#  'Satsumasendai',
#  'Sembonyama',
#  'Sekimachi',
#  'Sekigahara',
#  'Sekichō-furumaya',
#  'Sayō',
#  'Satte',
#  'Sasebo',
#  'Sasayama',
#  'Sasaguri',
#  'Sano',
#  'Sanjō',
#  'Sandachō',
#  'Sanmyō',
#  'Sanbashidōri',
#  'Sakurakabu',
#  'Sakurai',
#  'Sakurachō',
#  'Sakurabashidōri',
#  'Saku',
#  'Sakata',
#  'Ichinomiyamachi-sakanashi',
#  'Sakaki',
#  'Sakaiminato',
#  'Sakaidechō',
#  'Sakaidechō',
#  'Sakai-nakajima',
#  'Sakai',
#  'Sakai',
#  'Sakaguchi',
#  'Sakado',
#  'Saitama-ken',
#  'Saiki',
#  'Sagara',
#  'Sagamihara',
#  'Saga-ken',
#  'Saga',
#  'Sabae',
#  'Ryūō',
#  'Ryōtsu-minato',
#  'Ronji',
#  'Rokujizō',
#  'Renjakuchō',
#  'Ōzu',
#  'Oyama',
#  'Ōyama',
#  'Owase',
#  'Ōtsuki',
#  'Ōtsu',
#  'Ohtemachi',
#  'Ōtake',
#  'Ōta',
#  'Oshi',
#  'Ōsaka-fu',
#  'Osaka',
#  'Osaka',
#  'Onomichi',
#  'Onoda',
#  'Ono',
#  'Ono',
#  'Ōno-hara',
#  'Ono',
#  'Onna',
#  'Ōmuta',
#  'Ōmura',
#  'Ōmiyachō',
#  'Omi',
#  'Ōme',
#  'Ōmamachō-ōmama',
#  'Ōmachi',
#  'Ōkuchi-shinohara',
#  'Ōkubo-naka',
#  'Okinawa',
#  'Okegawa',
#  'Ōkagō',
#  'Okazaki',
#  'Okayama-ken',
#  'Okayama',
#  'Okaya',
#  'Ōkawa',
#  'Okata',
#  'Ojiya',
#  'Shinochō-ōji',
#  'Oita Prefecture',
#  'Ōita',
#  'Ōiso',
#  'Ōi',
#  'Ohama',
#  'Hama',
#  'Ōhama',
#  'Ogunimachi',
#  'Ogose',
#  'Ogōri-shimogō',
#  'Ōgimachiya',
#  'Ogimachi',
#  'Ogawa',
#  'Ogano',
#  'Ōgaki',
#  'Mitsushimachō-ōfunakoshi',
#  'Ōtera',
#  'Odawara',
#  'Ōdaka',
#  'Ōdachō-ōda',
#  'Ochiai',
#  'Obuse',
#  'Ōbu',
#  'Obita',
#  'Obama',
#  'Nyūzen',
#  'Numazu',
#  'Numata',
#  'Nosato',
#  'Nonoichi',
#  'Nōgata',
#  'Noda',
#  'Nobeoka',
#  'Nishizu',
#  'Nishiwaki',
#  'Nishio',
#  'Nishinoomote',
#  'Nishinomiya-hama',
#  'Nishikichō',
#  'Nishi-hanawa',
#  'Nishigochō',
#  'Nishihara',
#  'Nishi',
#  'Nirasaki',
#  'Ninomiya',
#  'Nikkō',
#  'Niitsu-honchō',
#  'Niimi',
#  'Niihama',
#  'Niigata-ken',
#  'Niigata',
#  'Nihon’ōdōri',
#  'Nichinan',
#  'Nerima',
#  'Nemoto',
#  'Naze',
#  'Nasuzukuri',
#  'Narutochō-mitsuishi',
#  'Narusawa',
#  'Nara-ken',
#  'Nara-shi',
#  'Nanukaichi',
#  'Nanao',
#  'Namerikawa',
#  'Nakijin',
#  'Nakayama',
#  'Nakatsugawa',
#  'Nakatsu',
#  'Nakatsu',
#  'Nakano',
#  'Nakanojōmachi',
#  'Nakano',
#  'Nakamura',
#  'Nakamura',
#  'Nakama',
#  'Nakajima',
#  'Nakaizumi',
#  'Nakaichi',
#  'Yamazakichō-nakai',
#  'Naka-gōchi',
#  'Nakagawa',
#  'Nahari',
#  'Naha',
#  'Nagoya',
#  'Nago',
#  'Nagasaki Prefecture',
#  'Nagasaki',
#  'Nagareyama',
#  'Nagaoka',
#  'Nagao',
#  'Nagano-ken',
#  'Naganohara',
#  'Nagano',
#  'Nagahamamachi',
#  'Nagahama',
#  'Nabari',
#  'Myōrakujichō',
#  'Musashino',
#  'Murotsu',
#  'Muroto-misakicho',
#  'Muramatsu',
#  'Murakami',
#  'Muraimachi-minami',
#  'Mukō',
#  'Mukai-awagasaki',
#  'Muikamachi',
#  'Mugiura',
#  'Motomachi',
#  'Motoichiba',
#  'Motogoe',
#  'Morohongō',
#  'Yamakunimachi-morizane',
#  'Moriyama',
#  'Moriguchi',
#  'Mori',
#  'Mizunami',
#  'Mizoguchi',
#  'Miyoshi-shi',
#  'Miyoshi',
#  'Miyazu',
#  'Miyazaki',
#  'Miyazaki',
#  'Miyamaechō',
#  'Miyakonojō',
#  'Miyake-naka',
#  'Miyajima',
#  'Miyaji',
#  'Miyada',
#  'Miyata',
#  'Miwa',
#  'Mitsuke',
#  'Mitsukaidō',
#  'Mitsugarasu',
#  'Mitake',
#  'Mitaka-shi',
#  'Mita',
#  'Mishima',
#  'Minowa',
#  'Mino',
#  'Minobu',
#  'Mino',
#  'Minatomachi',
#  'Minato',
#  'Minano',
#  'Minamisenju',
#  'Minamirinkan',
#  'Minamikasagi',
#  'Minamata',
#  'Minakuchichō-matoba',
#  'Minagi',
#  'Mikuni',
#  'Miki',
#  'Mihara',
#  'Mifune',
#  'Mie-ken',
#  'Mie',
#  'Mibu',
#  'Menuma',
#  'Mayanoheta',
#  'Matsuzaki',
#  'Matsutō',
#  'Matsuzaka-shi',
#  'Matsumoto',
#  'Matsugasakihama',
#  'Matsue',
#  'Matsudo',
#  'Matsubase',
#  'Matsubara',
#  'Matoba',
#  'Masuda',
#  'Maruoka',
#  'Marunouchi',
#  'Kamimaruko',
#  'Marugame',
#  'Manzawa',
#  'Bandaichō',
#  'Manazuru',
#  'Mameda-honmachi',
#  'Makurazaki',
#  'Makinohara',
#  'Maki',
#  'Maizuru',
#  'Maibara',
#  'Maehama',
#  'Maeda',
#  'Maebashi',
#  'Maebaru-chūō',
#  'Machida',
#  'Kyōto-shi',
#  'Kyoto Prefecture',
#  'Kyoto',
#  'Kyōguchi',
#  'Kuwana',
#  'Kushiro',
#  'Kushimoto',
#  'Kushikino',
#  'Kusatsu',
#  'Kurume',
#  'Kuroda',
#  'Kurihashi',
#  'Kure',
#  'Kurayoshi',
#  'Kurashiki',
#  'Kuradani',
#  'Kunigami',
#  'Kumamoto',
#  'Kumamoto',
#  'Kumagaya',
#  'Kukichūō',
#  'Kugayama',
#  'Kugamachi',
#  'Kudoyama',
#  'Kudamatsu',
#  'Kozakai-chō',
#  'Kotohira',
#  'Kōtari',
#  'Kuragaki-kosugi',
#  'Ko-shinozu',
#  'Koshigaya',
#  'Kosai-shi',
#  'Kōnosu',
#  'Kōnan',
#  'Komoro',
#  'Komono',
#  'Komatsushimachō',
#  'Komatsu',
#  'Komaki',
#  'Komagatamachi',
#  'Kokubunji',
#  'Kokubu-matsuki',
#  'Koganei',
#  'Koga',
#  'Koga',
#  'Kōfu',
#  'Kodamachō-kodamaminami',
#  'Kodaira',
#  'Kochino',
#  'Kochi Prefecture',
#  'Kōchi',
#  'Kochi',
#  'Kobe',
#  'Kobayashi',
#  'Kobaruyama',
#  'Kiyama',
#  'Kitsuki',
#  'Kita-toyama',
#  'Kitakyushu',
#  'Kitakata',
#  'Kitahama',
#  'Kitadaishin',
#  'Kishiwada',
#  'Kisarazu',
#  'Kisai',
#  'Kiryū',
#  'Kiragawachō',
#  'Kin',
#  'Kimiidera',
#  'Kikuna',
#  'Kikuchi',
#  'Kazo',
#  'Kawatana',
#  'Kawasaki',
#  'Kawasaki',
#  'Kawanishi',
#  'Kawamoto',
#  'Kawai',
#  'Kawaguchi',
#  'Kawagoe',
#  'Katsuyama',
#  'Katase',
#  'Kasukabe',
#  'Kasugai',
#  'Kasugabaru',
#  'Kasuga',
#  'Kashiwazaki',
#  'Kashiwara',
#  'Kashiwano',
#  'Kashiwa',
#  'Kashima',
#  'Kashihara-shi',
#  'Kashihara',
#  'Kaseda-shirakame',
#  'Kasaoka',
#  'Kasamatsuchō',
#  'Karochō',
#  'Kariya',
#  'Kariwa',
#  'Karatsu',
#  'Kanzakimachi-kanzaki',
#  'Kanuma',
#  'Kanoya',
#  'Kan’onjichō',
#  'Kannabechō-yahiro',
#  'Kanie',
#  'Kanekomachi',
#  'Kanda',
#  'Kanazu',
#  'Kanazawa',
#  'Kanazawachō',
#  'Kanayama',
#  'Kanaya',
#  'Kanagawa',
#  'Mitsu-kanagawa',
#  'Kamonomiya',
#  'Kamojimachō-jōgejima',
#  'Kamogatachō-kamogata',
#  'Kamo',
#  'Hirosechō-kamiyamasa',
#  'Kamirenjaku',
#  'Kaminokawa',
#  'Kami-nagarekawachō',
#  'Kamikōjaku',
#  'Kamiichi',
#  'Kamigōri',
#  'Kameyama',
#  'Kameoka',
#  'Kameda-honchō',
#  'Kameari',
#  'Kamakura',
#  'Kakogawachō-honmachi',
#  'Kakegawa',
#  'Kakamigahara',
#  'Kashima-shi',
#  'Kajiki',
#  'Kaizuka',
#  'Kainan',
#  'Kaigandōri',
#  'Kagoshima-ken',
#  'Kagoshima',
#  'Kagawa-ken',
#  'Kagasuno',
#  'Kagamizu',
#  'Kadoma',
#  'Kadogawa',
#  'Kado',
#  'Kachikawa',
#  'Jūrokuban',
#  'Jizōdō',
#  'Terauchi',
#  'Jigozen',
#  'Japan',
#  'Izumo',
#  'Izumiōtsu',
#  'Izumi',
#  'Izumi',
#  'Izuhara',
#  'Izena',
#  'Iwatsuki',
#  'Iwata',
#  'Iwanogawa',
#  'Mitsuchō-iwami',
#  'Iwakura',
#  'Iwakuni',
#  'Iwai',
#  'Iwade',
#  'Itsukaichi',
#  'Itoman',
#  'Itoigawa',
#  'Itō',
#  'Itazuke',
#  'Ikedachō-itano',
#  'Itami',
#  'Itakura',
#  'Isoshi',
#  'Ishiki',
#  'Ishikawa-ken',
#  'Ishikawa',
#  'Ishii',
#  'Ishige',
#  'Ishigaki',
#  'Isesaki',
#  'Isehara',
#  'Ise',
#  'Isawa',
#  'Isahaya',
#  'Inuyama',
#  'Ino',
#  'Innoshima',
#  'Ishidachō-indōjiura',
#  'Inazawa',
#  'Ina',
#  'Ina',
#  'Imazu',
#  'Imarichō-kō',
#  'Imaichi',
#  'Ikoma',
#  'Ikeda',
#  'Ikeda',
#  'Ikeda',
#  'Ikedachō',
#  'Ikaruga',
#  'Ijūin',
#  'Iizuka',
#  'Iiyama',
#  'Iijima',
#  'Iida',
#  'Iga-shi',
#  'Ifukugata',
#  'Ichinomiya',
#  'Ichinomiyachō',
#  'Ichikawa',
#  'Ibusuki',
#  'Ibaraki',
#  'Ibara',
#  'Hyōgo',
#  'Hotaka',
#  'Hōryūji',
#  'Horinouchi',
#  'Honjōchō',
#  'Honjō',
#  'Hondomachi-hondo',
#  'Hōjō',
#  'Hōjōchō-hōjō',
#  'Hōfu',
#  'Hitoyoshi',
#  'Okuhida-onsengō-hitoegane',
#  'Hita',
#  'Hisai-motomachi',
#  'Hiroshima-ken',
#  'Hiroshima',
#  'Hirokawa',
#  'Hiratsuka',
#  'Hiratachō',
#  'Hirara',
#  'Hirao',
#  'Hirakata',
#  'Hirakata',
#  'Hiradogoyamachi',
#  'Hirado',
#  'Hioki',
#  'Hinokage',
#  'Hino',
#  'Hino',
#  'Himimachi',
#  'Himeji',
#  'Hikosan',
#  'Hikone',
#  'Hiji',
#  'Suminoe-higashi',
#  'Higashishinagawa',
#  'Higashi-ōsaka',
#  'Higashimachi',
#  'Higashiboridōri',
#  'Higashiasahimachi',
#  'Higashi',
#  'Hekinan',
#  'Heda',
#  'Hayashima',
#  'Hayashi',
#  'Hayama',
#  'Hayakawa',
#  'Hatsukaichi',
#  'Hatogaya-honchō',
#  'Hatabuchō',
#  'Hashio',
#  'Hashimoto',
#  'Harisakichō',
#  'Harigaya',
#  'Hara',
#  'Hanyū',
#  'Hannō',
#  'Handa',
#  'Hanazawa',
#  'Hanawadamachi',
#  'Hanabatachō',
#  'Hamanose',
#  'Hamanoichi',
#  'Hamanaka',
#  'Hamamatsu',
#  'Hamakita',
#  'Hamada',
#  'Hakui',
#  'Hakonegasaki',
#  'Hakone',
#  'Hainuzuka',
#  'Haibara-akanedai',
#  'Hagiwara',
#  'Hagi',
#  'Katsuren-haebaru',
#  'Hadano',
#  'Hachiōji',
#  'Ōmihachiman',
#  'Habu',
#  'Gyōda',
#  'Gushikawa',
#  'Gunma-ken',
#  'Goyuchō',
#  'Gōtsuchō',
#  'Gotenba',
#  'Gosen',
#  'Gose',
#  'Gojō',
#  'Gōdo',
#  'Gobō',
#  'Ginoza',
#  'Ginowan',
#  'Gifu',
#  'Gifu-shi',
#  'Ganeko',
#  'Gamagōri',
#  'Futtsu',
#  'Fushimi',
#  'Kōfukuchō',
#  'Furuichi',
#  'Furuichi',
#  'Furugen',
#  'Funato',
#  'Honchō',
#  'Fukuyama',
#  'Fukuroi',
#  'Fukura',
#  'Fukuoka Prefecture',
#  'Fukuoka',
#  'Fukumitsu',
#  'Nishifukuma',
#  'Fukui',
#  'Fukui-shi',
#  'Fukuechō',
#  'Fukuchiyama',
#  'Fukiage-fujimi',
#  'Fukayachō',
#  'Fujisawa',
#  'Fujioka',
#  'Fujioka',
#  'Fujinomiya',
#  'Fujieda',
#  'Fuji',
#  'Fuchu',
#  'Fuchūchō',
#  'Enzan',
#  'Ehime',
#  'Egota',
#  'Egashira',
#  'Edome-naka',
#  'Echigawa',
#  'Dōshi',
#  'Den’enchōfu',
#  'Daitōchō',
#  'Daisen',
#  'Daidō',
#  'Chōfu',
#  'Chizu',
#  'Chiyoda-ku',
#  'Chiryū',
#  'Chino',
#  'Chikushino-shi',
#  'Chigasaki',
#  'Chichibu',
#  'Chatan',
#  'Chabana',
#  'Buzen-shi',
#  'Beppu',
#  'Bentenchō',
#  'Ichibanchō',
#  'Bakurochō',
#  'Ayabe',
#  'Aya',
#  'Awatabe',
#  'Awara',
#  'Atami',
#  'Ataka-shimmachi',
#  'Ashiya',
#  'Ashikaga',
#  'Ashihara',
#  'Asahi',
#  'Asagaya-minami',
#  'Arita',
#  'Arimatsu',
#  'Arai',
#  'Aoki',
#  'Aoichō',
#  'Annaka',
#  'Anjō',
#  'Anan',
#  'Anamizu',
#  'Amagi',
#  'Amagasaki',
#  'Akune',
#  'Akuchi',
#  'Kariya',
#  'Aki',
#  'Akashichō',
#  'Aioi',
#  'Aichi-ken',
#  'Ageoshimo',
#  'Agematsu',
#  'Ageki',
#  'Motobu',
#  'Okinawa',
#  'Urazoe',
#  'Haebaru',
#  'Kushima',
#  'Hikari',
#  'Kaita',
#  'Seirō',
#  'Mirukashi',
#  'Yakataishi',
#  'Nagato',
#  'Nakai',
#  'Hasuda',
#  'Kamifukuoka',
#  'Sayama',
#  'Fussa',
#  'Fujino',
#  'Kunitachi',
#  'Okura',
#  'Minawa',
#  'Kawara',
#  'Miyanomae',
#  'Takata',
#  'Koyasu',
#  'Asaka',
#  'Wako',
#  'Shimotoda',
#  'Komae',
#  'Kimitsu',
#  'Miura',
#  'Wakayama',
#  'Iyo',
#  'Yokogawara',
#  'Uwajima',
#  'Tsutsui',
#  'Tsuitachi',
#  'Saijō',
#  'Ōzu',
#  'Matsuyama',
#  ...]

# %%
from collections import Counter
name_counter = Counter(city_list_nameonly)
print(name_counter)

for name in selected_cities_name:
    count = name_counter.get(name, 0)
    if count == 0:
        print(f'{name}: 見つからない')
    elif count == 1:
        print(f'{name}: 重複なし...OK!')
    else:
        print(f'{name}: 重複あり')
# Out:
# Counter({'Honchō': 5, 'Asahi': 4, 'Minato': 3, 'Ono': 3, 'Motomachi': 3, 'Ikeda': 3, 'Shingū': 2, 'Yuzawa': 2, 'Yoshii': 2, 'Yokohama': 2, 'Honmachi': 2, 'Yamaguchi': 2, 'Wakayama': 2, 'Tottori': 2, 'Tomioka': 2, 'Tochigi': 2, 'Tanabe': 2, 'Takata': 2, 'Takamatsu': 2, 'Suwa': 2, 'Shizuoka': 2, 'Shiozawa': 2, 'Sakaidechō': 2, 'Sakai': 2, 'Ōzu': 2, 'Osaka': 2, 'Okinawa': 2, 'Nakayama': 2, 'Nakatsu': 2, 'Nakano': 2, 'Nakamura': 2, 'Nakagawa': 2, 'Miyazaki': 2, 'Mino': 2, 'Kushiro': 2, 'Kumamoto': 2, 'Komatsu': 2, 'Koga': 2, 'Kawasaki': 2, 'Kasuga': 2, 'Kariya': 2, 'Izumi': 2, 'Ishikawa': 2, 'Ina': 2, 'Ibaraki': 2, 'Hōjō': 2, 'Hirakata': 2, 'Hino': 2, 'Hashimoto': 2, 'Furuichi': 2, 'Fujioka': 2, 'Tsukuba': 2, 'Ōmagari': 2, 'Odaka': 2, 'Hanawa': 2, 'Akita': 2, 'Misawa': 2, 'Hachinohe': 2, 'Atsugi': 1, 'Akashi': 1, 'Zushi': 1, 'Awazuchō': 1, 'Zaōmachi': 1, 'Zamami': 1, 'Zama': 1, 'Yuza': 1, 'Yusuhara': 1, 'Yūrakuchō': 1, 'Yura': 1, 'Yukuhashi': 1, 'Yūki': 1, 'Yugawara': 1, 'Yugawa': 1, 'Yuasa': 1, 'Yoshino-chō': 1, 'Yoshikawa': 1, 'Yoshie': 1, 'Yoshida-kasugachō': 1, 'Yoshida': 1, 'Miimachi-yoromi': 1, 'Yorii': 1, 'Yono': 1, 'Yonakuni': 1, 'Yonago': 1, 'Yonabaru': 1, 'Yokota': 1, 'Yokosuka': 1, 'Yokodaidō': 1, 'Yokkaichi': 1, 'Youkaichi': 1, 'Yobimatsu': 1, 'Yawata': 1, 'Yatsuzawa': 1, 'Yatsuomachi-higashikumisaka': 1, 'Yasugichō': 1, 'Yasu-shi': 1, 'Yashiro': 1, 'Yashio': 1, 'Yaotsu': 1, 'Yao': 1, 'Yanohama': 1, 'Yanai': 1, 'Yanagawa': 1, 'Yanadachō': 1, 'Yamato-Takada': 1, 'Yamatominami': 1, 'Yamata': 1, 'Yamazakichō-nakabirose': 1, 'Yamanashi': 1, 'Yamakita': 1, 'Yamaga': 1, 'Yamae': 1, 'Yakuin-Horibata': 1, 'Yakage': 1, 'Yaizu': 1, 'Yaita': 1, 'Yabutani': 1, 'Yabuhana': 1, 'Yabu': 1, 'Warabo': 1, 'Warabi': 1, 'Wano': 1, 'Wakinohamachō': 1, 'Wakimachi': 1, 'Wake': 1, 'Wakasa': 1, 'Wajima': 1, 'Wadomari': 1, 'Wadayama': 1, 'Utsunomiya': 1, 'Uto': 1, 'Utazu': 1, 'Usuki': 1, 'Ushibukamachi': 1, 'Usa': 1, 'Ureshinomachi-shimojuku': 1, 'Urayasu': 1, 'Uozu': 1, 'Uno': 1, 'Umi': 1, 'Uki': 1, 'Uken': 1, 'Ujiie': 1, 'Uji': 1, 'Uenohara': 1, 'Ueno': 1, 'Ueno-ebisumachi': 1, 'Ueki': 1, 'Uekimachi-mōno': 1, 'Ueda': 1, 'Ube': 1, 'Tsuyama': 1, 'Tsushima': 1, 'Tsurusaki': 1, 'Tsuruoka': 1, 'Tsurugi-asahimachi': 1, 'Tsurugasaki': 1, 'Tsuruga': 1, 'Tsunō': 1, 'Tsunagi': 1, 'Tsuma': 1, 'Tsukumiura': 1, 'Tsukawaki': 1, 'Tsukasamachi': 1, 'Tsukaguchichō': 1, 'Tsuiki': 1, 'Tsubota': 1, 'Tsubata': 1, 'Tsubame': 1, 'Tsu': 1, 'Tozawa': 1, 'Toyota-shi': 1, 'Toyota': 1, 'Toyoshina': 1, 'Toyooka': 1, 'Toyonaka': 1, 'Toyokawa': 1, 'Toyohashi': 1, 'Toyohama': 1, 'Toyama-ken': 1, 'Toyama': 1, 'Totsuka chō': 1, 'Tosu': 1, 'Toriimatsu': 1, 'Tonoshō': 1, 'Tondabayashichō': 1, 'Tonami': 1, 'Tomigusuku': 1, 'Tokyo Prefecture': 1, 'Tokyo': 1, 'Tokuyama': 1, 'Tokushima-ken': 1, 'Tokushima': 1, 'Tokuda': 1, 'Tokorozawa': 1, 'Tokoname': 1, 'Toki': 1, 'Tokashiki': 1, 'Tōkamachi': 1, 'Tōkaichi': 1, 'Tōji': 1, 'Togitsu': 1, 'Todaka': 1, 'Tochio-honchō': 1, 'Tōbō': 1, 'Toba': 1, 'Tenri': 1, 'Tennō': 1, 'Tenjin': 1, 'Tenjimmae': 1, 'Tawaramoto': 1, 'Tatsuno': 1, 'Tatsunochō-tominaga': 1, 'Tateyama': 1, 'Tatebayashi': 1, 'Tarumizu': 1, 'Tarui': 1, 'Taragi': 1, 'Tanushimarumachi-toyoki': 1, 'Tanuma': 1, 'Nishi-Tokyo-shi': 1, 'Tanashichō': 1, 'Tamba': 1, 'Tamarai': 1, 'Tamano': 1, 'Tamana': 1, 'Tamamura': 1, 'Tamagawa': 1, 'Taketoyo': 1, 'Taketomi': 1, 'Takeochō-takeo': 1, 'Takenouchi': 1, 'Takehara': 1, 'Takefu': 1, 'Takedamachi': 1, 'Takayama': 1, 'Takatsuki': 1, 'Takatsu': 1, 'Takatorichō': 1, 'Takatachō': 1, 'Takasaki': 1, 'Takasagochō-takasemachi': 1, 'Takarazuka': 1, 'Takaoka': 1, 'Takanabe': 1, 'Takamori': 1, 'Takajōmachi': 1, 'Takaishi': 1, 'Takahashi': 1, 'Takaharu': 1, 'Takahama': 1, 'Bungo-Takada-shi': 1, 'Tajimi': 1, 'Tahara': 1, 'Tagawa': 1, 'Taga': 1, 'Tadotsu': 1, 'Tadami': 1, 'Tachikawa': 1, 'Tachiarai': 1, 'Tabuse': 1, 'Suzuka': 1, 'Suzaka': 1, 'Susami': 1, 'Susaki': 1, 'Sumoto': 1, 'Sukumo': 1, 'Suita': 1, 'Suibara': 1, 'Suguri': 1, 'Sugito': 1, 'Sueyoshichō ...
# Wakkanai: 重複なし...OK!
# Sapporo: 重複なし...OK!
# Sendai: 重複なし...OK!
# Niigata: 重複なし...OK!
# Tokyo: 重複なし...OK!
# Kanazawa: 重複なし...OK!
# Nagano: 重複なし...OK!
# Osaka: 重複あり
# Fukuyama: 重複なし...OK!
# Kochi: 重複なし...OK!
# Fukuoka: 重複なし...OK!
# Kagoshima: 重複なし...OK!
# Naha: 重複なし...OK!
# Nagoya: 重複なし...OK!
# Aomori: 重複なし...OK!
# Matsue: 重複なし...OK!

# %%
# 集計したい都市名とAPIから引っ張る緯度経度をくっつけるためにクラスを作る
class City:
    def __init__(self, name, lat, lon, name_ja):
        self.name = name
        self.lat = lat
        self.lon = lon
        self.name_ja = name_ja

    # 確認用
    def city_print(self):
        print(f'name: {self.name}, lat: {self.lat}, lon: {self.lon}, name_ja: {self.name_ja}')

    # dict型にしないとjsonファイルとして出力できないことが判明したため、メソッドを追加
    def todict(self):
        return {
            'name': self.name,
            'lat': self.lat,
            'lon': self.lon,
            'name_ja': self.name_ja,
        }

# %%
selected_cities_list = []

for name in selected_cities_name:
    # urlについて：{name}は都市名、その後ろの,JPは国名指定。これを付けないと海外の同名都市が引っかかってしまう
    url = f'http://api.openweathermap.org/geo/1.0/direct?q={name},JP&limit=1&appid={API_key}'
    jsondata = requests.get(url).json()
    new_city = City(
        name = name,
        lat = jsondata[0]['lat'],
        lon = jsondata[0]['lon'],
        name_ja = jsondata[0]['local_names']['ja']
    )
    selected_cities_list.append(new_city)

# %%
for i in selected_cities_list:
    i.city_print()
# Out:
# name: Wakkanai, lat: 45.4158108, lon: 141.6730309, name_ja: 稚内市
# name: Sapporo, lat: 43.061936, lon: 141.3542924, name_ja: 札幌市
# name: Sendai, lat: 38.2677554, lon: 140.8691498, name_ja: 仙台市
# name: Niigata, lat: 37.9160769, lon: 139.0365006, name_ja: 新潟市
# name: Tokyo, lat: 35.6768601, lon: 139.7638947, name_ja: 東京都
# name: Kanazawa, lat: 36.561627, lon: 136.6568822, name_ja: 金沢市
# name: Nagano, lat: 36.6485851, lon: 138.1947664, name_ja: 長野市
# name: Osaka, lat: 34.6937569, lon: 135.5014539, name_ja: 大阪市
# name: Fukuyama, lat: 34.4857039, lon: 133.3623097, name_ja: 福山市
# name: Kochi, lat: 33.5680384, lon: 133.5394221, name_ja: 高知市
# name: Fukuoka, lat: 33.5898988, lon: 130.4017509, name_ja: 福岡市
# name: Kagoshima, lat: 31.5841689, lon: 130.543387, name_ja: 鹿児島市
# name: Naha, lat: 26.2122345, lon: 127.6791452, name_ja: 那覇市
# name: Nagoya, lat: 35.1851045, lon: 136.8998438, name_ja: 名古屋市
# name: Aomori, lat: 40.8221517, lon: 140.7471238, name_ja: 青森市
# name: Matsue, lat: 35.468115, lon: 133.048768, name_ja: 松江市

# %%
with open("location.json", mode="w", encoding="utf-8") as f:
    json.dump([City.todict(city) for city in selected_cities_list], f, ensure_ascii=False, indent=2)
